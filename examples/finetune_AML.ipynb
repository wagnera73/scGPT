# %% [markdown]
# # Finetune AML data

# %% [markdown]
# ## Working through batch integration tutorial with AML data

# %%
import copy
import gc
import json
import os
from pathlib import Path
import sys
import time
import traceback
from typing import List, Tuple, Dict, Union, Optional
import warnings

import torch
from anndata import AnnData
import scanpy as sc
import scvi
import numpy as np
import wandb
from scipy.sparse import issparse
import matplotlib.pyplot as plt
from torch import nn
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from torchtext.vocab import Vocab
from torchtext._torchtext import (
    Vocab as VocabPybind,
)
sys.path.append("../")

from scgpt.tokenizer.gene_tokenizer import GeneVocab

import scgpt as scg
from scgpt.model import TransformerModel, AdversarialDiscriminator
from scgpt.tokenizer import tokenize_and_pad_batch, random_mask_value
from scgpt.loss import (
    masked_mse_loss,
    masked_relative_error,
    criterion_neg_log_bernoulli,
)
from scgpt.preprocess import Preprocessor
from scgpt import SubsetsBatchSampler
from scgpt.utils import set_seed, category_str2int, eval_scib_metrics, load_pretrained

sc.set_figure_params(figsize=(4, 4))
os.environ["KMP_WARNINGS"] = "off"
# os.environ["WANDB_MODE"] = "offline"

hyperparameter_defaults = dict(
    seed=42,
    dataset_name="AML",
    do_train=True,
    load_model="../save/scGPT_kidney",
    mask_ratio=0.4,
    epochs=10,
    n_bins=51,
    GEPC=True,  # Masked value prediction for cell embedding
    ecs_thres=0.8,  # Elastic cell similarity objective, 0.0 to 1.0, 0.0 to disable
    dab_weight=1.0,
    lr=1e-4,
    batch_size=32,
    layer_size=128,
    nlayers=4,
    nhead=4,
    # if load model, batch_size, layer_size, nlayers, nhead will be ignored
    dropout=0.2,
    schedule_ratio=0.9,  # ratio of epochs for learning rate schedule
    save_eval_interval=5,
    log_interval=100,
    fast_transformer=True,
    pre_norm=False,
    amp=True,  # Automatic Mixed Precision
)
run = wandb.init(
    config=hyperparameter_defaults,
    project="scGPT",
    reinit=True,
    settings=wandb.Settings(start_method="fork"),
)
config = wandb.config
print(config)

set_seed(config.seed)
# Out:
# c:\Users\wag9iz\AppData\Local\anaconda3\envs\rtd\lib\site-packages\torch\nn\modules\transformer.py:20: UserWarning: Failed to initialize NumPy: DLL load failed while importing _multiarray_umath: The specified module could not be found. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_numpy.cpp:84.)
#   device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# c:\Users\wag9iz\AppData\Local\anaconda3\envs\rtd\lib\site-packages\h5py\__init__.py:36: UserWarning: h5py is running against HDF5 1.14.6 when it was built against 1.14.5, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 15
#      13 from anndata import AnnData
#      14 import scanpy as sc
# ---> 15 import scvi
#      16 import numpy as np
#      17 import wandb
#
# File c:\Users\wag9iz\AppData\Local\anaconda3\envs\rtd\lib\site-packages\scvi\__init__.py:11
#       8 from ._settings import settings
#      10 # this import needs to come after prior imports to prevent circular import
# ---> 11 from . import data, model, external, utils
#      13 from importlib.metadata import version
#      15 package_name = "scvi-tools"
#
# File c:\Users\wag9iz\AppData\Local\anaconda3\envs\rtd\lib\site-packages\scvi\data\__init__.py:3
#       1 from anndata import read_csv, read_h5ad, read_loom, read_text
# ----> 3 from ._anntorchdataset import AnnTorchDataset
#       4 from ._datasets import (
#       5     annotation_simulation,
#       6     brainlarge_dataset,
#    (...)
#      22     synthetic_iid,
#      23 )
#      24 from ._manager import AnnDataManager, AnnDataManagerValidationCheck
#
# File c:\Users\wag9iz\AppData\Local\anaconda3\envs\rtd\lib\site-packages\scvi\data\_anntorchdataset.py:27
#      25 if TYPE_CHECKING:
#      26     from ._manager import AnnDataManager
# ---> 27 from ._utils import registry_key_to_default_dtype, scipy_to_torch_sparse
#      29 logger = logging.getLogger(__name__)
#      32 class AnnTorchDataset(Dataset):
#
# File c:\Users\wag9iz\AppData\Local\anaconda3\envs\rtd\lib\site-packages\scvi\data\_utils.py:29
#      26 except ImportError:
#      27     from anndata._io.specs import read_elem
# ---> 29 from mudata import MuData
#      30 from pandas.api.types import CategoricalDtype
#      31 from torch import as_tensor, sparse_csc_tensor, sparse_csr_tensor
#
# File c:\Users\wag9iz\AppData\Local\anaconda3\envs\rtd\lib\site-packages\mudata\__init__.py:3
#       1 """Multimodal omics analysis framework"""
# ----> 3 from ._core.mudata import MuData
#       4 from ._core import utils
#       5 from ._core.io import *
#
# File c:\Users\wag9iz\AppData\Local\anaconda3\envs\rtd\lib\site-packages\mudata\_core\mudata.py:21
#      19 from anndata import AnnData
#      20 from anndata.utils import convert_to_dict
# ---> 21 from anndata._core.aligned_mapping import (
#      22     AxisArrays,
#      23     AlignedViewMixin,
#      24     AxisArraysBase,
#      25     PairwiseArrays,
#      26     PairwiseArraysView,
#      27 )
#      28 from anndata._core.views import DataFrameView
#      30 from .file_backing import MuDataFileManager
#
# ImportError: cannot import name 'AlignedViewMixin' from 'anndata._core.aligned_mapping' (c:\Users\wag9iz\AppData\Local\anaconda3\envs\rtd\lib\site-packages\anndata\_core\aligned_mapping.py)

# %%
# settings for input and preprocessing
pad_token = "<pad>"
special_tokens = [pad_token, "<cls>", "<eoc>"]
mask_ratio = config.mask_ratio
mask_value = -1
pad_value = -2
n_input_bins = config.n_bins

n_hvg = 500  # number of highly variable genes
max_seq_len = n_hvg + 1
per_seq_batch_sample = True
DSBN = True  # Domain-spec batchnorm
explicit_zero_prob = True  # whether explicit bernoulli for zeros

# %%
dataset_name = config.dataset_name
save_dir = Path(f"./save/dev_{dataset_name}-{time.strftime('%b%d-%H-%M')}/")
save_dir.mkdir(parents=True, exist_ok=True)
print(f"save to {save_dir}")
# save the whole script to the dir

script_path = os.path.join(os.getcwd(), 'finetune_AML.ipynb')  # Or adjust for your specific case
os.system(f"cp {script_path} {save_dir}")
#os.system(f"cp {__file__} {save_dir}")

logger = scg.logger
scg.utils.add_file_handler(logger, save_dir / "run.log")
# Out:
# save to save/dev_AML-Feb05-12-52

# %%
print(os.getcwd())
# Out:
# /data/xu_lab_projectsx/Andrew/Foundation_Test/scGPT/scGPT-main/examples

# %%
# ## Loading and preparing data
if dataset_name == "PBMC_10K":
    adata = scvi.data.pbmc_dataset()  # 11990 × 3346
    ori_batch_col = "batch"
    adata.obs["celltype"] = adata.obs["str_labels"].astype("category")
    adata.var = adata.var.set_index("gene_symbols")
    data_is_raw = True
else:
    adata = sc.read_h5ad("../data/AML_All_Samples.h5ad")
    ori_batch_col = "ID"
    adata.obs["celltype"] = adata.obs["AnnoCellType"].astype("category")
    adata.obs["condition"] = adata.obs["disease"].astype("category")
    #adata.var = adata.var.set_index("var.features")
    data_is_raw = True
# Out:
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/compat/__init__.py:229: FutureWarning: Moving element from .uns['neighbors']['distances'] to .obsp['distances'].
#
# This is where adjacency matrices should go now.
#   warn(

# %%
# make the batch category column
adata.obs["str_batch"] = adata.obs[ori_batch_col].astype(str)
batch_id_labels = adata.obs["str_batch"].astype("category").cat.codes.values
adata.obs["batch_id"] = batch_id_labels

adata.var["gene_name"] = adata.var.index.tolist()

if config.load_model is not None:
    model_dir = Path(config.load_model)
    model_config_file = model_dir / "args.json"
    model_file = model_dir / "best_model.pt"
    vocab_file = model_dir / "vocab.json"

    vocab = GeneVocab.from_file(vocab_file)
    for s in special_tokens:
        if s not in vocab:
            vocab.append_token(s)

    adata.var["id_in_vocab"] = [
        1 if gene in vocab else -1 for gene in adata.var["gene_name"]
    ]
    gene_ids_in_vocab = np.array(adata.var["id_in_vocab"])
    logger.info(
        f"match {np.sum(gene_ids_in_vocab >= 0)}/{len(gene_ids_in_vocab)} genes "
        f"in vocabulary of size {len(vocab)}."
    )
    adata = adata[:, adata.var["id_in_vocab"] >= 0]

    # model
    with open(model_config_file, "r") as f:
        model_configs = json.load(f)
    logger.info(
        f"Resume model from {model_file}, the model args will be overriden by the "
        f"config {model_config_file}."
    )
    embsize = model_configs["embsize"]
    nhead = model_configs["nheads"]
    d_hid = model_configs["d_hid"]
    nlayers = model_configs["nlayers"]
    n_layers_cls = model_configs["n_layers_cls"]
else:
    embsize = config.layer_size
    nhead = config.nhead
    nlayers = config.nlayers
    d_hid = config.layer_size
# Out:
# scGPT - INFO - match 30766/38851 genes in vocabulary of size 60697.
# scGPT - INFO - Resume model from ../save/scGPT_kidney/best_model.pt, the model args will be overriden by the config ../save/scGPT_kidney/args.json.

# %% [markdown]
# ## 2.3 Pre-process the data

# %%
# set up the preprocessor, use the args to config the workflow
preprocessor = Preprocessor(
    use_key="X",  # the key in adata.layers to use as raw data
    filter_gene_by_counts=3,  # step 1
    filter_cell_by_counts=False,  # step 2
    normalize_total=1e4,  # 3. whether to normalize the raw data and to what sum
    result_normed_key="X_normed",  # the key in adata.layers to store the normalized data
    log1p=data_is_raw,  # 4. whether to log1p the normalized data
    result_log1p_key="X_log1p",
    subset_hvg=n_hvg,  # 5. whether to subset the raw data to highly variable genes
    hvg_flavor="seurat_v3" if data_is_raw else "cell_ranger",
    binning=config.n_bins,  # 6. whether to bin the raw data and to what number of bins
    result_binned_key="X_binned",  # the key in adata.layers to store the binned data
)
preprocessor(adata, batch_key="str_batch" if dataset_name != "heart_cell" else None)
# Out:
# scGPT - INFO - Filtering genes by counts ...
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scanpy/preprocessing/_simple.py:281: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata.var["n_counts"] = number
# scGPT - INFO - Normalizing total counts ...
# scGPT - INFO - Log1p transforming ...
# scGPT - WARNING - The input data seems to be already log1p transformed. Set `log1p=False` to avoid double log1p transform.
# scGPT - INFO - Subsetting highly variable genes ...
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scanpy/preprocessing/_highly_variable_genes.py:75: UserWarning: `flavor='seurat_v3'` expects raw count data, but non-integers were found.
#   warnings.warn(
# scGPT - INFO - Binning data ...

# %%
if per_seq_batch_sample:
    # sort the adata by batch_id in advance
    adata_sorted = adata[adata.obs["batch_id"].argsort()].copy()

# %% [markdown]
# ## 2.4 Tokenize input data for finetuning

# %%
input_layer_key = "X_binned"
all_counts = (
    adata.layers[input_layer_key].A
    if issparse(adata.layers[input_layer_key])
    else adata.layers[input_layer_key]
)
genes = adata.var["gene_name"].tolist()

celltypes_labels = adata.obs["celltype"].tolist()  # make sure count from 0
num_types = len(set(celltypes_labels))
celltypes_labels = np.array(celltypes_labels)

batch_ids = adata.obs["batch_id"].tolist()
num_batch_types = len(set(batch_ids))
batch_ids = np.array(batch_ids)

(
    train_data,
    valid_data,
    train_celltype_labels,
    valid_celltype_labels,
    train_batch_labels,
    valid_batch_labels,
) = train_test_split(
    all_counts, celltypes_labels, batch_ids, test_size=0.1, shuffle=True
)

# %%
if config.load_model is None:
    vocab = Vocab(
        VocabPybind(genes + special_tokens, None)
    )  # bidirectional lookup [gene <-> int]
vocab.set_default_index(vocab["<pad>"])
gene_ids = np.array(vocab(genes), dtype=int)

# %%
tokenized_train = tokenize_and_pad_batch(
    train_data,
    gene_ids,
    max_len=max_seq_len,
    vocab=vocab,
    pad_token=pad_token,
    pad_value=pad_value,
    append_cls=True,  # append <cls> token at the beginning
    include_zero_gene=True,
)
tokenized_valid = tokenize_and_pad_batch(
    valid_data,
    gene_ids,
    max_len=max_seq_len,
    vocab=vocab,
    pad_token=pad_token,
    pad_value=pad_value,
    append_cls=True,
    include_zero_gene=True,
)
logger.info(
    f"train set number of samples: {tokenized_train['genes'].shape[0]}, "
    f"\n\t feature length: {tokenized_train['genes'].shape[1]}"
)
logger.info(
    f"valid set number of samples: {tokenized_valid['genes'].shape[0]}, "
    f"\n\t feature length: {tokenized_valid['genes'].shape[1]}"
)
# Out:
# scGPT - INFO - train set number of samples: 122368,
# 	 feature length: 501
# scGPT - INFO - valid set number of samples: 13597,
# 	 feature length: 501

# %%
def prepare_data(sort_seq_batch=False) -> Tuple[Dict[str, torch.Tensor]]:
    masked_values_train = random_mask_value(
        tokenized_train["values"],
        mask_ratio=mask_ratio,
        mask_value=mask_value,
        pad_value=pad_value,
    )
    masked_values_valid = random_mask_value(
        tokenized_valid["values"],
        mask_ratio=mask_ratio,
        mask_value=mask_value,
        pad_value=pad_value,
    )
    print(
        f"random masking at epoch {epoch:3d}, ratio of masked values in train: ",
        f"{(masked_values_train == mask_value).sum() / (masked_values_train - pad_value).count_nonzero():.4f}",
    )

    input_gene_ids_train, input_gene_ids_valid = (
        tokenized_train["genes"],
        tokenized_valid["genes"],
    )
    input_values_train, input_values_valid = masked_values_train, masked_values_valid
    target_values_train, target_values_valid = (
        tokenized_train["values"],
        tokenized_valid["values"],
    )

    tensor_batch_labels_train = torch.from_numpy(train_batch_labels).long()
    tensor_batch_labels_valid = torch.from_numpy(valid_batch_labels).long()

    if sort_seq_batch:
        train_sort_ids = np.argsort(train_batch_labels)
        input_gene_ids_train = input_gene_ids_train[train_sort_ids]
        input_values_train = input_values_train[train_sort_ids]
        target_values_train = target_values_train[train_sort_ids]
        tensor_batch_labels_train = tensor_batch_labels_train[train_sort_ids]

        valid_sort_ids = np.argsort(valid_batch_labels)
        input_gene_ids_valid = input_gene_ids_valid[valid_sort_ids]
        input_values_valid = input_values_valid[valid_sort_ids]
        target_values_valid = target_values_valid[valid_sort_ids]
        tensor_batch_labels_valid = tensor_batch_labels_valid[valid_sort_ids]

    train_data_pt = {
        "gene_ids": input_gene_ids_train,
        "values": input_values_train,
        "target_values": target_values_train,
        "batch_labels": tensor_batch_labels_train,
    }
    valid_data_pt = {
        "gene_ids": input_gene_ids_valid,
        "values": input_values_valid,
        "target_values": target_values_valid,
        "batch_labels": tensor_batch_labels_valid,
    }

    return train_data_pt, valid_data_pt


# dataset
class SeqDataset(Dataset):
    def __init__(self, data: Dict[str, torch.Tensor]):
        self.data = data

    def __len__(self):
        return self.data["gene_ids"].shape[0]

    def __getitem__(self, idx):
        return {k: v[idx] for k, v in self.data.items()}


# data_loader
def prepare_dataloader(
    data_pt: Dict[str, torch.Tensor],
    batch_size: int,
    shuffle: bool = False,
    intra_domain_shuffle: bool = False,
    drop_last: bool = False,
    num_workers: int = 0,
) -> DataLoader:
    dataset = SeqDataset(data_pt)

    if per_seq_batch_sample:
        # find the indices of samples in each seq batch
        subsets = []
        batch_labels_array = data_pt["batch_labels"].numpy()
        for batch_label in np.unique(batch_labels_array):
            batch_indices = np.where(batch_labels_array == batch_label)[0].tolist()
            subsets.append(batch_indices)
        data_loader = DataLoader(
            dataset=dataset,
            batch_sampler=SubsetsBatchSampler(
                subsets,
                batch_size,
                intra_subset_shuffle=intra_domain_shuffle,
                inter_subset_shuffle=shuffle,
                drop_last=drop_last,
            ),
            num_workers=num_workers,
            pin_memory=True,
        )
        return data_loader

    data_loader = DataLoader(
        dataset=dataset,
        batch_size=batch_size,
        shuffle=shuffle,
        drop_last=drop_last,
        num_workers=num_workers,
        pin_memory=True,
    )
    return data_loader

# %% [markdown]
# # Step 3

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print('Device available: ',device)
print('Batch size: ',config.batch_size)
# Out:
# Device available:  cuda
# Batch size:  32

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print('Device available: ',device)
ntokens = len(vocab)  # size of vocabulary
model = TransformerModel(
    ntokens,
    embsize,
    nhead,
    d_hid,
    nlayers,
    vocab=vocab,
    dropout=config.dropout,
    pad_token=pad_token,
    pad_value=pad_value,
    do_mvc=config.GEPC,
    do_dab=True,
    use_batch_labels=True,
    num_batch_labels=num_batch_types,
    domain_spec_batchnorm=DSBN,
    n_input_bins=n_input_bins,
    ecs_threshold=config.ecs_thres,
    explicit_zero_prob=explicit_zero_prob,
    use_fast_transformer=config.fast_transformer,
    pre_norm=config.pre_norm,
)
if config.load_model is not None:
    load_pretrained(model, torch.load(model_file), verbose=False)

model.to(device)
wandb.watch(model)
# Out:
# Device available:  cuda
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scgpt/model/model.py:77: UserWarning: flash-attn is not installed, using pytorch transformer instead. Set use_fast_transformer=False to avoid this warning. Installing flash-attn is highly recommended.
#   warnings.warn(
# Use domain specific batchnorm with affine=False

# %%
criterion = masked_mse_loss
criterion_dab = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(
    model.parameters(), lr=config.lr, eps=1e-4 if config.amp else 1e-8
)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1, gamma=config.schedule_ratio)
scaler = torch.cuda.amp.GradScaler(enabled=config.amp)

# %%
def train(model: nn.Module, loader: DataLoader) -> None:
    """
    Train the model for one epoch.
    """
    model.train()
    total_loss, total_mse, total_gepc = 0.0, 0.0, 0.0
    total_error = 0.0
    log_interval = config.log_interval
    start_time = time.time()

    num_batches = len(loader)
    for batch, batch_data in enumerate(loader):
        input_gene_ids = batch_data["gene_ids"].to(device)
        input_values = batch_data["values"].to(device)
        target_values = batch_data["target_values"].to(device)
        batch_labels = batch_data["batch_labels"].to(device)

        src_key_padding_mask = input_gene_ids.eq(vocab[pad_token])
        with torch.cuda.amp.autocast(enabled=config.amp):
            output_dict = model(
                input_gene_ids,
                input_values,
                src_key_padding_mask=src_key_padding_mask,
                batch_labels=batch_labels if DSBN else None,
                MVC=config.GEPC,
                ECS=config.ecs_thres > 0,
            )

            masked_positions = input_values.eq(mask_value)  # the postions to predict
            loss = loss_mse = criterion(
                output_dict["mlm_output"], target_values, masked_positions
            )
            metrics_to_log = {"train/mse": loss_mse.item()}
            if explicit_zero_prob:
                loss_zero_log_prob = criterion_neg_log_bernoulli(
                    output_dict["mlm_zero_probs"], target_values, masked_positions
                )
                loss = loss + loss_zero_log_prob
                metrics_to_log.update({"train/nzlp": loss_zero_log_prob.item()})
            if config.GEPC:
                loss_gepc = criterion(
                    output_dict["mvc_output"], target_values, masked_positions
                )
                loss = loss + loss_gepc
                metrics_to_log.update({"train/mvc": loss_gepc.item()})
            if config.GEPC and explicit_zero_prob:
                loss_gepc_zero_log_prob = criterion_neg_log_bernoulli(
                    output_dict["mvc_zero_probs"], target_values, masked_positions
                )
                loss = loss + loss_gepc_zero_log_prob
                metrics_to_log.update(
                    {"train/mvc_nzlp": loss_gepc_zero_log_prob.item()}
                )
            if config.ecs_thres > 0:
                loss_ecs = 10 * output_dict["loss_ecs"]
                loss = loss + loss_ecs
                metrics_to_log.update({"train/ecs": loss_ecs.item()})
            loss_dab = criterion_dab(output_dict["dab_output"], batch_labels)
            loss = loss + config.dab_weight * loss_dab
            metrics_to_log.update({"train/dab": loss_dab.item()})

        model.zero_grad()
        scaler.scale(loss).backward()
        scaler.unscale_(optimizer)
        with warnings.catch_warnings(record=True) as w:
            warnings.filterwarnings("always")
            torch.nn.utils.clip_grad_norm_(
                model.parameters(),
                1.0,
                error_if_nonfinite=False if scaler.is_enabled() else True,
            )
            if len(w) > 0:
                logger.warning(
                    f"Found infinite gradient. This may be caused by the gradient "
                    f"scaler. The current scale is {scaler.get_scale()}. This warning "
                    "can be ignored if no longer occurs after autoscaling of the scaler."
                )
        scaler.step(optimizer)
        scaler.update()

        wandb.log(metrics_to_log)

        with torch.no_grad():
            mre = masked_relative_error(
                output_dict["mlm_output"], target_values, masked_positions
            )

        total_loss += loss.item()
        total_mse += loss_mse.item()
        total_gepc += loss_gepc.item() if config.GEPC else 0.0
        total_error += mre.item()
        if batch % log_interval == 0 and batch > 0:
            lr = scheduler.get_last_lr()[0]
            ms_per_batch = (time.time() - start_time) * 1000 / log_interval
            cur_loss = total_loss / log_interval
            cur_mse = total_mse / log_interval
            cur_gepc = total_gepc / log_interval if config.GEPC else 0.0
            cur_error = total_error / log_interval
            # ppl = math.exp(cur_loss)
            logger.info(
                f"| epoch {epoch:3d} | {batch:3d}/{num_batches:3d} batches | "
                f"lr {lr:05.4f} | ms/batch {ms_per_batch:5.2f} | "
                f"loss {cur_loss:5.2f} | mse {cur_mse:5.2f} | mre {cur_error:5.2f} |"
                + (f"gepc {cur_gepc:5.2f} |" if config.GEPC else "")
            )
            total_loss = 0
            total_mse = 0
            total_gepc = 0
            total_error = 0
            start_time = time.time()


def define_wandb_metrcis():
    wandb.define_metric("valid/mse", summary="min", step_metric="epoch")
    wandb.define_metric("valid/mre", summary="min", step_metric="epoch")
    wandb.define_metric("valid/dab", summary="min", step_metric="epoch")
    wandb.define_metric("valid/sum_mse_dab", summary="min", step_metric="epoch")
    wandb.define_metric("test/avg_bio", summary="max")


def evaluate(model: nn.Module, loader: DataLoader) -> float:
    """
    Evaluate the model on the evaluation data.
    """
    model.eval()
    total_loss = 0.0
    total_error = 0.0
    total_dab = 0.0
    total_num = 0
    with torch.no_grad():
        for batch_data in loader:
            input_gene_ids = batch_data["gene_ids"].to(device)
            input_values = batch_data["values"].to(device)
            target_values = batch_data["target_values"].to(device)
            batch_labels = batch_data["batch_labels"].to(device)

            src_key_padding_mask = input_gene_ids.eq(vocab[pad_token])
            with torch.cuda.amp.autocast(enabled=config.amp):
                output_dict = model(
                    input_gene_ids,
                    input_values,
                    src_key_padding_mask=src_key_padding_mask,
                    batch_labels=batch_labels if DSBN else None,
                )
                output_values = output_dict["mlm_output"]

                masked_positions = input_values.eq(mask_value)
                loss = criterion(output_values, target_values, masked_positions)
                loss_dab = criterion_dab(output_dict["dab_output"], batch_labels)

            total_loss += loss.item() * len(input_gene_ids)
            total_error += masked_relative_error(
                output_values, target_values, masked_positions
            ).item() * len(input_gene_ids)
            total_dab += loss_dab.item() * len(input_gene_ids)
            total_num += len(input_gene_ids)

    wandb.log(
        {
            "valid/mse": total_loss / total_num,
            "valid/mre": total_error / total_num,
            "valid/dab": total_dab / total_num,
            "valid/sum_mse_dab": (total_loss + config.dab_weight * total_dab)
            / total_num,
            "epoch": epoch,
        },
    )

    return total_loss / total_num, total_error / total_num


def eval_testdata(
    model: nn.Module,
    adata_t: AnnData,
    include_types: List[str] = ["cls"],
) -> Optional[Dict]:
    """evaluate the model on test dataset of adata_t"""
    model.eval()

    # copy adata_t to avoid reuse previously computed results stored in adata_t
    adata_t = adata_t.copy()

    all_counts = (
        adata_t.layers[input_layer_key].A
        if issparse(adata_t.layers[input_layer_key])
        else adata_t.layers[input_layer_key]
    )

    celltypes_labels = adata_t.obs["celltype"].tolist()
    celltypes_labels = np.array(celltypes_labels)

    batch_ids = adata_t.obs["batch_id"].tolist()
    batch_ids = np.array(batch_ids)

    # Evaluate cls cell embeddings
    if "cls" in include_types:
        logger.info("Evaluating cls cell embeddings")
        tokenized_all = tokenize_and_pad_batch(
            all_counts,
            gene_ids,
            max_len=max_seq_len,
            vocab=vocab,
            pad_token=pad_token,
            pad_value=pad_value,
            append_cls=True,  # append <cls> token at the beginning
            include_zero_gene=True,
        )
        all_gene_ids, all_values = tokenized_all["genes"], tokenized_all["values"]
        src_key_padding_mask = all_gene_ids.eq(vocab[pad_token])
        with torch.no_grad(), torch.cuda.amp.autocast(enabled=config.amp):
            cell_embeddings = model.encode_batch(
                all_gene_ids,
                all_values.float(),
                src_key_padding_mask=src_key_padding_mask,
                batch_size=config.batch_size,
                batch_labels=torch.from_numpy(batch_ids).long() if DSBN else None,
                time_step=0,
                return_np=True,
            )
        cell_embeddings = cell_embeddings / np.linalg.norm(
            cell_embeddings, axis=1, keepdims=True
        )

        adata_t.obsm["X_scGPT"] = cell_embeddings

        results = {}
        try:
            results = eval_scib_metrics(adata_t)
        except Exception as e:
            traceback.print_exc()
            logger.error(e)

        sc.pp.neighbors(adata_t, use_rep="X_scGPT")
        sc.tl.umap(adata_t, min_dist=0.3)
        fig = sc.pl.umap(
            adata_t,
            color=["str_batch"],
            title=[f"batch, avg_bio = {results.get('avg_bio', 0.0):.4f}"],
            frameon=False,
            return_fig=True,
            show=False,
        )

        results["batch_umap"] = fig

        sc.pp.neighbors(adata_t, use_rep="X_scGPT")
        sc.tl.umap(adata_t, min_dist=0.3)
        fig = sc.pl.umap(
            adata_t,
            color=["celltype"],
            title=[
                f"celltype, avg_bio = {results.get('avg_bio', 0.0):.4f}",
            ],
            frameon=False,
            return_fig=True,
            show=False,
        )

        results["celltype_umap"] = fig

    if len(include_types) == 1:
        return results

# %% [markdown]
# ## Step 4: Finetune scGPT with task-specific objectives

# %%
best_val_loss = float("inf")
best_avg_bio = 0.0
best_model = None
define_wandb_metrcis()

for epoch in range(1, config.epochs + 1):
    epoch_start_time = time.time()
    train_data_pt, valid_data_pt = prepare_data(sort_seq_batch=per_seq_batch_sample)
    train_loader = prepare_dataloader(
        train_data_pt,
        batch_size=config.batch_size,
        shuffle=False,
        intra_domain_shuffle=True,
        drop_last=False,
    )
    valid_loader = prepare_dataloader(
        valid_data_pt,
        batch_size=config.batch_size,
        shuffle=False,
        intra_domain_shuffle=False,
        drop_last=False,
    )

    if config.do_train:
        train(
            model,
            loader=train_loader,
        )
    val_loss, val_mre = evaluate(
        model,
        loader=valid_loader,
    )
    elapsed = time.time() - epoch_start_time
    logger.info("-" * 89)
    logger.info(
        f"| end of epoch {epoch:3d} | time: {elapsed:5.2f}s | "
        f"valid loss/mse {val_loss:5.4f} | mre {val_mre:5.4f}"
    )
    logger.info("-" * 89)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model = copy.deepcopy(model)
        best_model_epoch = epoch
        logger.info(f"Best model with score {best_val_loss:5.4f}")

    if epoch % config.save_eval_interval == 0 or epoch == config.epochs:
        logger.info(f"Saving model to {save_dir}")
        torch.save(best_model.state_dict(), save_dir / f"model_e{best_model_epoch}.pt")

        # eval on testdata
        results = eval_testdata(
            best_model,
            adata_t=adata_sorted if per_seq_batch_sample else adata,
            include_types=["cls"],
        )
        results["batch_umap"].savefig(
            save_dir / f"embeddings_batch_umap[cls]_e{best_model_epoch}.png", dpi=300
        )

        results["celltype_umap"].savefig(
            save_dir / f"embeddings_celltype_umap[cls]_e{best_model_epoch}.png", dpi=300
        )
        metrics_to_log = {"test/" + k: v for k, v in results.items()}
        metrics_to_log["test/batch_umap"] = wandb.Image(
            str(save_dir / f"embeddings_batch_umap[cls]_e{best_model_epoch}.png"),
            caption=f"celltype avg_bio epoch {best_model_epoch}",
        )

        metrics_to_log["test/celltype_umap"] = wandb.Image(
            str(save_dir / f"embeddings_celltype_umap[cls]_e{best_model_epoch}.png"),
            caption=f"celltype avg_bio epoch {best_model_epoch}",
        )
        metrics_to_log["test/best_model_epoch"] = best_model_epoch
        wandb.log(metrics_to_log)
        wandb.log({"avg_bio": results.get("avg_bio", 0.0)})

    scheduler.step()
# Out:
# random masking at epoch   1, ratio of masked values in train:  0.3992
# scGPT - INFO - | epoch   1 | 100/3829 batches | lr 0.0001 | ms/batch 289.91 | loss 157.16 | mse 68.56 | mre 2234404.79 |gepc 76.85 |
# scGPT - INFO - | epoch   1 | 200/3829 batches | lr 0.0001 | ms/batch 174.17 | loss 81.58 | mse 40.73 | mre 1250324.76 |gepc 30.62 |
# scGPT - INFO - | epoch   1 | 300/3829 batches | lr 0.0001 | ms/batch 171.14 | loss 69.51 | mse 26.80 | mre 740540.14 |gepc 32.15 |
# scGPT - INFO - | epoch   1 | 400/3829 batches | lr 0.0001 | ms/batch 171.12 | loss 58.84 | mse 20.91 | mre 591468.80 |gepc 27.88 |
# scGPT - INFO - | epoch   1 | 500/3829 batches | lr 0.0001 | ms/batch 171.08 | loss 55.46 | mse 19.70 | mre 547693.56 |gepc 25.76 |
# scGPT - INFO - | epoch   1 | 600/3829 batches | lr 0.0001 | ms/batch 171.13 | loss 53.87 | mse 19.15 | mre 536093.12 |gepc 25.02 |
# scGPT - INFO - | epoch   1 | 700/3829 batches | lr 0.0001 | ms/batch 171.14 | loss 50.95 | mse 18.95 | mre 544318.93 |gepc 23.13 |
# scGPT - INFO - | epoch   1 | 800/3829 batches | lr 0.0001 | ms/batch 171.13 | loss 48.84 | mse 18.04 | mre 488683.20 |gepc 22.89 |
# scGPT - INFO - | epoch   1 | 900/3829 batches | lr 0.0001 | ms/batch 171.15 | loss 48.85 | mse 18.41 | mre 497170.90 |gepc 22.48 |
# scGPT - INFO - | epoch   1 | 1000/3829 batches | lr 0.0001 | ms/batch 178.13 | loss 48.02 | mse 18.09 | mre 489199.75 |gepc 22.09 |
# scGPT - INFO - | epoch   1 | 1100/3829 batches | lr 0.0001 | ms/batch 171.30 | loss 47.74 | mse 18.16 | mre 520543.16 |gepc 21.80 |
# scGPT - INFO - | epoch   1 | 1200/3829 batches | lr 0.0001 | ms/batch 172.17 | loss 63.43 | mse 20.66 | mre 680992.78 |gepc 32.29 |
# scGPT - INFO - | epoch   1 | 1300/3829 batches | lr 0.0001 | ms/batch 171.22 | loss 46.81 | mse 15.81 | mre 453459.57 |gepc 21.32 |
# scGPT - INFO - | epoch   1 | 1400/3829 batches | lr 0.0001 | ms/batch 171.32 | loss 43.02 | mse 14.98 | mre 437489.31 |gepc 19.20 |
# scGPT - INFO - | epoch   1 | 1500/3829 batches | lr 0.0001 | ms/batch 171.38 | loss 41.75 | mse 15.16 | mre 424066.71 |gepc 18.92 |
# scGPT - INFO - | epoch   1 | 1600/3829 batches | lr 0.0001 | ms/batch 171.23 | loss 40.18 | mse 14.59 | mre 404045.89 |gepc 17.92 |
# scGPT - INFO - | epoch   1 | 1700/3829 batches | lr 0.0001 | ms/batch 170.82 | loss 70.03 | mse 23.52 | mre 703741.73 |gepc 35.77 |
# scGPT - INFO - | epoch   1 | 1800/3829 batches | lr 0.0001 | ms/batch 171.21 | loss 61.15 | mse 21.18 | mre 662727.12 |gepc 30.85 |
# scGPT - INFO - | epoch   1 | 1900/3829 batches | lr 0.0001 | ms/batch 171.32 | loss 58.65 | mse 20.43 | mre 610348.30 |gepc 29.63 |
# scGPT - INFO - | epoch   1 | 2000/3829 batches | lr 0.0001 | ms/batch 172.30 | loss 56.45 | mse 20.17 | mre 595881.96 |gepc 28.11 |
# scGPT - INFO - | epoch   1 | 2100/3829 batches | lr 0.0001 | ms/batch 171.32 | loss 61.15 | mse 20.37 | mre 703869.08 |gepc 32.43 |
# scGPT - INFO - | epoch   1 | 2200/3829 batches | lr 0.0001 | ms/batch 171.24 | loss 54.11 | mse 19.74 | mre 590602.66 |gepc 26.22 |
# scGPT - INFO - | epoch   1 | 2300/3829 batches | lr 0.0001 | ms/batch 171.38 | loss 48.87 | mse 18.89 | mre 554782.00 |gepc 23.36 |
# scGPT - INFO - | epoch   1 | 2400/3829 batches | lr 0.0001 | ms/batch 171.44 | loss 48.24 | mse 18.88 | mre 545642.72 |gepc 23.02 |
# scGPT - INFO - | epoch   1 | 2500/3829 batches | lr 0.0001 | ms/batch 171.30 | loss 46.22 | mse 18.67 | mre 552057.02 |gepc 21.35 |
# scGPT - INFO - | epoch   1 | 2600/3829 batches | lr 0.0001 | ms/batch 170.49 | loss 58.75 | mse 23.24 | mre 679472.53 |gepc 27.27 |
# scGPT - INFO - | epoch   1 | 2700/3829 batches | lr 0.0001 | ms/batch 171.27 | loss 56.27 | mse 19.72 | mre 639285.19 |gepc 27.41 |
# scGPT - INFO - | epoch   1 | 2800/3829 batches | lr 0.0001 | ms/batch 171.44 | loss 43.60 | mse 15.05 | mre 431475.03 |gepc 19.98 |
# scGPT - INFO - | epoch   1 | 2900/3829 batches | lr 0.0001 | ms/batch 171.24 | loss 41.27 | mse 14.48 | mre 423890.80 |gepc 18.86 |
# scGPT - INFO - | epoch   1 | 3000/3829 batches | lr 0.0001 | ms/batch 172.78 | loss 57.04 | mse 20.62 | mre 581657.62 |gepc 28.13 |
# scGPT - INFO - | epoch   1 | 3100/3829 batches | lr 0.0001 | ms/batch 171.53 | loss 49.42 | mse 19.04 | mre 517863.45 |gepc 23.90 |
# scGPT - INFO - | epoch   1 | 3200/3829 batches | lr 0.0001 | ms/batch 171.55 | loss 46.16 | mse 17.91 | mre 491553.13 |gepc 21.91 |
# scGPT - INFO - | epoch   1 | 3300/3829 batches | lr 0.0001 | ms/batch 171.71 | loss 45.23 | mse 17.71 | mre 485094.32 |gepc 21.22 |
# scGPT - INFO - | epoch   1 | 3400/3829 batches | lr 0.0001 | ms/batch 171.62 | loss 44.18 | mse 17.45 | mre 475951.09 |gepc 20.52 |
# scGPT - INFO - | epoch   1 | 3500/3829 batches | lr 0.0001 | ms/batch 170.91 | loss 59.87 | mse 20.66 | mre 651036.21 |gepc 28.85 |
# scGPT - INFO - | epoch   1 | 3600/3829 batches | lr 0.0001 | ms/batch 171.49 | loss 54.58 | mse 21.96 | mre 606246.21 |gepc 25.53 |
# scGPT - INFO - | epoch   1 | 3700/3829 batches | lr 0.0001 | ms/batch 171.48 | loss 52.30 | mse 20.82 | mre 559604.29 |gepc 25.16 |
# scGPT - INFO - | epoch   1 | 3800/3829 batches | lr 0.0001 | ms/batch 171.48 | loss 50.17 | mse 20.42 | mre 545849.89 |gepc 23.44 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   1 | time: 695.11s | valid loss/mse 24.4621 | mre 396497.0745
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 24.4621
# random masking at epoch   2, ratio of masked values in train:  0.3992
# scGPT - INFO - | epoch   2 | 100/3829 batches | lr 0.0001 | ms/batch 173.02 | loss 95.85 | mse 24.45 | mre 672054.61 |gepc 59.87 |
# scGPT - INFO - | epoch   2 | 200/3829 batches | lr 0.0001 | ms/batch 172.77 | loss 49.16 | mse 17.51 | mre 479203.48 |gepc 24.19 |
# scGPT - INFO - | epoch   2 | 300/3829 batches | lr 0.0001 | ms/batch 172.02 | loss 49.32 | mse 18.16 | mre 479853.41 |gepc 22.53 |
# scGPT - INFO - | epoch   2 | 400/3829 batches | lr 0.0001 | ms/batch 172.00 | loss 42.93 | mse 16.15 | mre 429861.55 |gepc 19.70 |
# scGPT - INFO - | epoch   2 | 500/3829 batches | lr 0.0001 | ms/batch 171.88 | loss 42.10 | mse 16.15 | mre 431706.13 |gepc 19.12 |
# scGPT - INFO - | epoch   2 | 600/3829 batches | lr 0.0001 | ms/batch 171.88 | loss 41.62 | mse 16.27 | mre 448443.28 |gepc 18.88 |
# scGPT - INFO - | epoch   2 | 700/3829 batches | lr 0.0001 | ms/batch 171.83 | loss 40.46 | mse 15.98 | mre 423578.33 |gepc 17.93 |
# scGPT - INFO - | epoch   2 | 800/3829 batches | lr 0.0001 | ms/batch 172.06 | loss 40.80 | mse 16.14 | mre 431003.02 |gepc 18.17 |
# scGPT - INFO - | epoch   2 | 900/3829 batches | lr 0.0001 | ms/batch 171.88 | loss 40.38 | mse 15.91 | mre 410907.81 |gepc 18.14 |
# scGPT - INFO - | epoch   2 | 1000/3829 batches | lr 0.0001 | ms/batch 172.03 | loss 40.47 | mse 16.05 | mre 422559.06 |gepc 18.21 |
# scGPT - INFO - | epoch   2 | 1100/3829 batches | lr 0.0001 | ms/batch 172.00 | loss 39.86 | mse 15.81 | mre 417369.93 |gepc 17.60 |
# scGPT - INFO - | epoch   2 | 1200/3829 batches | lr 0.0001 | ms/batch 173.69 | loss 44.52 | mse 15.50 | mre 431252.01 |gepc 20.29 |
# scGPT - INFO - | epoch   2 | 1300/3829 batches | lr 0.0001 | ms/batch 171.77 | loss 38.87 | mse 14.19 | mre 399800.78 |gepc 17.58 |
# scGPT - INFO - | epoch   2 | 1400/3829 batches | lr 0.0001 | ms/batch 171.81 | loss 36.81 | mse 13.65 | mre 371120.12 |gepc 16.38 |
# scGPT - INFO - | epoch   2 | 1500/3829 batches | lr 0.0001 | ms/batch 171.83 | loss 36.46 | mse 13.51 | mre 374787.72 |gepc 16.29 |
# scGPT - INFO - | epoch   2 | 1600/3829 batches | lr 0.0001 | ms/batch 171.75 | loss 36.28 | mse 13.55 | mre 368216.47 |gepc 16.14 |
# scGPT - INFO - | epoch   2 | 1700/3829 batches | lr 0.0001 | ms/batch 170.91 | loss 55.32 | mse 19.96 | mre 560397.31 |gepc 26.85 |
# scGPT - INFO - | epoch   2 | 1800/3829 batches | lr 0.0001 | ms/batch 171.86 | loss 46.69 | mse 19.09 | mre 566864.93 |gepc 21.79 |
# scGPT - INFO - | epoch   2 | 1900/3829 batches | lr 0.0001 | ms/batch 171.89 | loss 45.03 | mse 18.85 | mre 559828.87 |gepc 20.56 |
# scGPT - INFO - | epoch   2 | 2000/3829 batches | lr 0.0001 | ms/batch 171.83 | loss 45.15 | mse 19.00 | mre 556492.90 |gepc 20.64 |
# scGPT - INFO - | epoch   2 | 2100/3829 batches | lr 0.0001 | ms/batch 171.87 | loss 46.02 | mse 18.46 | mre 549007.69 |gepc 21.27 |
# scGPT - INFO - | epoch   2 | 2200/3829 batches | lr 0.0001 | ms/batch 173.03 | loss 43.79 | mse 17.37 | mre 508387.64 |gepc 19.92 |
# scGPT - INFO - | epoch   2 | 2300/3829 batches | lr 0.0001 | ms/batch 171.66 | loss 42.57 | mse 17.17 | mre 499613.63 |gepc 19.71 |
# scGPT - INFO - | epoch   2 | 2400/3829 batches | lr 0.0001 | ms/batch 171.87 | loss 42.42 | mse 17.39 | mre 511125.98 |gepc 19.53 |
# scGPT - INFO - | epoch   2 | 2500/3829 batches | lr 0.0001 | ms/batch 171.99 | loss 42.09 | mse 17.33 | mre 510428.62 |gepc 19.24 |
# scGPT - INFO - | epoch   2 | 2600/3829 batches | lr 0.0001 | ms/batch 170.94 | loss 67.30 | mse 23.26 | mre 678492.47 |gepc 35.16 |
# scGPT - INFO - | epoch   2 | 2700/3829 batches | lr 0.0001 | ms/batch 174.70 | loss 51.02 | mse 18.27 | mre 529907.51 |gepc 24.38 |
# scGPT - INFO - | epoch   2 | 2800/3829 batches | lr 0.0001 | ms/batch 171.52 | loss 38.21 | mse 13.62 | mre 385861.72 |gepc 17.21 |
# scGPT - INFO - | epoch   2 | 2900/3829 batches | lr 0.0001 | ms/batch 171.68 | loss 37.35 | mse 13.52 | mre 382204.39 |gepc 16.87 |
# scGPT - INFO - | epoch   2 | 3000/3829 batches | lr 0.0001 | ms/batch 171.92 | loss 50.12 | mse 18.38 | mre 499746.27 |gepc 24.39 |
# scGPT - INFO - | epoch   2 | 3100/3829 batches | lr 0.0001 | ms/batch 171.66 | loss 42.84 | mse 16.83 | mre 460559.82 |gepc 20.28 |
# scGPT - INFO - | epoch   2 | 3200/3829 batches | lr 0.0001 | ms/batch 172.77 | loss 41.98 | mse 16.73 | mre 433440.30 |gepc 19.51 |
# scGPT - INFO - | epoch   2 | 3300/3829 batches | lr 0.0001 | ms/batch 171.59 | loss 40.93 | mse 16.41 | mre 451575.08 |gepc 18.93 |
# scGPT - INFO - | epoch   2 | 3400/3829 batches | lr 0.0001 | ms/batch 171.74 | loss 40.42 | mse 16.34 | mre 443650.82 |gepc 18.54 |
# scGPT - INFO - | epoch   2 | 3500/3829 batches | lr 0.0001 | ms/batch 171.18 | loss 59.72 | mse 18.61 | mre 562730.56 |gepc 31.84 |
# scGPT - INFO - | epoch   2 | 3600/3829 batches | lr 0.0001 | ms/batch 171.62 | loss 50.79 | mse 20.67 | mre 549567.97 |gepc 23.64 |
# scGPT - INFO - | epoch   2 | 3700/3829 batches | lr 0.0001 | ms/batch 171.79 | loss 48.26 | mse 20.05 | mre 527929.02 |gepc 22.22 |
# scGPT - INFO - | epoch   2 | 3800/3829 batches | lr 0.0001 | ms/batch 171.88 | loss 46.78 | mse 19.42 | mre 519724.74 |gepc 21.60 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   2 | time: 684.04s | valid loss/mse 20.5394 | mre 439623.7893
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 20.5394
# random masking at epoch   3, ratio of masked values in train:  0.3992
# scGPT - INFO - | epoch   3 | 100/3829 batches | lr 0.0001 | ms/batch 173.12 | loss 57.90 | mse 20.48 | mre 549160.96 |gepc 27.92 |
# scGPT - INFO - | epoch   3 | 200/3829 batches | lr 0.0001 | ms/batch 171.33 | loss 40.64 | mse 15.90 | mre 436764.68 |gepc 18.49 |
# scGPT - INFO - | epoch   3 | 300/3829 batches | lr 0.0001 | ms/batch 172.13 | loss 46.31 | mse 16.84 | mre 434680.68 |gepc 21.14 |
# scGPT - INFO - | epoch   3 | 400/3829 batches | lr 0.0001 | ms/batch 173.10 | loss 39.89 | mse 15.77 | mre 421695.01 |gepc 17.74 |
# scGPT - INFO - | epoch   3 | 500/3829 batches | lr 0.0001 | ms/batch 171.99 | loss 39.34 | mse 15.69 | mre 403614.70 |gepc 17.40 |
# scGPT - INFO - | epoch   3 | 600/3829 batches | lr 0.0001 | ms/batch 171.91 | loss 38.76 | mse 15.41 | mre 408152.36 |gepc 17.34 |
# scGPT - INFO - | epoch   3 | 700/3829 batches | lr 0.0001 | ms/batch 171.98 | loss 39.21 | mse 15.53 | mre 410977.90 |gepc 17.36 |
# scGPT - INFO - | epoch   3 | 800/3829 batches | lr 0.0001 | ms/batch 172.05 | loss 39.14 | mse 15.40 | mre 410730.80 |gepc 17.63 |
# scGPT - INFO - | epoch   3 | 900/3829 batches | lr 0.0001 | ms/batch 172.09 | loss 38.35 | mse 15.38 | mre 415447.07 |gepc 16.88 |
# scGPT - INFO - | epoch   3 | 1000/3829 batches | lr 0.0001 | ms/batch 172.02 | loss 38.26 | mse 15.44 | mre 412566.98 |gepc 16.80 |
# scGPT - INFO - | epoch   3 | 1100/3829 batches | lr 0.0001 | ms/batch 172.01 | loss 37.69 | mse 15.17 | mre 402818.37 |gepc 16.47 |
# scGPT - INFO - | epoch   3 | 1200/3829 batches | lr 0.0001 | ms/batch 172.43 | loss 52.50 | mse 14.88 | mre 429193.11 |gepc 28.60 |
# scGPT - INFO - | epoch   3 | 1300/3829 batches | lr 0.0001 | ms/batch 171.84 | loss 36.00 | mse 13.43 | mre 367293.90 |gepc 15.47 |
# scGPT - INFO - | epoch   3 | 1400/3829 batches | lr 0.0001 | ms/batch 172.91 | loss 34.96 | mse 13.12 | mre 364886.55 |gepc 15.30 |
# scGPT - INFO - | epoch   3 | 1500/3829 batches | lr 0.0001 | ms/batch 171.82 | loss 35.21 | mse 13.45 | mre 351426.16 |gepc 15.35 |
# scGPT - INFO - | epoch   3 | 1600/3829 batches | lr 0.0001 | ms/batch 171.85 | loss 34.26 | mse 12.92 | mre 358210.52 |gepc 15.04 |
# scGPT - INFO - | epoch   3 | 1700/3829 batches | lr 0.0001 | ms/batch 170.79 | loss 55.98 | mse 19.48 | mre 556382.94 |gepc 28.44 |
# scGPT - INFO - | epoch   3 | 1800/3829 batches | lr 0.0001 | ms/batch 171.76 | loss 45.40 | mse 18.67 | mre 548028.92 |gepc 21.26 |
# scGPT - INFO - | epoch   3 | 1900/3829 batches | lr 0.0001 | ms/batch 171.84 | loss 44.03 | mse 18.24 | mre 536492.39 |gepc 20.43 |
# scGPT - INFO - | epoch   3 | 2000/3829 batches | lr 0.0001 | ms/batch 171.77 | loss 43.05 | mse 17.83 | mre 518321.81 |gepc 19.95 |
# scGPT - INFO - | epoch   3 | 2100/3829 batches | lr 0.0001 | ms/batch 171.93 | loss 44.00 | mse 17.87 | mre 541420.51 |gepc 20.19 |
# scGPT - INFO - | epoch   3 | 2200/3829 batches | lr 0.0001 | ms/batch 171.75 | loss 43.10 | mse 16.97 | mre 493861.07 |gepc 19.35 |
# scGPT - INFO - | epoch   3 | 2300/3829 batches | lr 0.0001 | ms/batch 171.74 | loss 39.81 | mse 16.56 | mre 483956.84 |gepc 17.99 |
# scGPT - INFO - | epoch   3 | 2400/3829 batches | lr 0.0001 | ms/batch 173.06 | loss 40.59 | mse 16.95 | mre 497624.01 |gepc 18.42 |
# scGPT - INFO - | epoch   3 | 2500/3829 batches | lr 0.0001 | ms/batch 171.91 | loss 40.12 | mse 16.81 | mre 485438.46 |gepc 18.12 |
# scGPT - INFO - | epoch   3 | 2600/3829 batches | lr 0.0001 | ms/batch 170.68 | loss 54.67 | mse 20.92 | mre 601889.77 |gepc 25.67 |
# scGPT - INFO - | epoch   3 | 2700/3829 batches | lr 0.0001 | ms/batch 171.43 | loss 63.51 | mse 17.50 | mre 481292.47 |gepc 37.17 |
# scGPT - INFO - | epoch   3 | 2800/3829 batches | lr 0.0001 | ms/batch 171.86 | loss 39.61 | mse 13.28 | mre 376455.68 |gepc 18.76 |
# scGPT - INFO - | epoch   3 | 2900/3829 batches | lr 0.0001 | ms/batch 171.70 | loss 37.92 | mse 12.97 | mre 361652.69 |gepc 17.85 |
# scGPT - INFO - | epoch   3 | 3000/3829 batches | lr 0.0001 | ms/batch 171.92 | loss 44.42 | mse 17.03 | mre 463942.15 |gepc 20.54 |
# scGPT - INFO - | epoch   3 | 3100/3829 batches | lr 0.0001 | ms/batch 171.80 | loss 40.84 | mse 16.16 | mre 437887.06 |gepc 19.21 |
# scGPT - INFO - | epoch   3 | 3200/3829 batches | lr 0.0001 | ms/batch 171.89 | loss 39.38 | mse 16.06 | mre 432079.46 |gepc 17.95 |
# scGPT - INFO - | epoch   3 | 3300/3829 batches | lr 0.0001 | ms/batch 171.73 | loss 38.70 | mse 15.75 | mre 419456.08 |gepc 17.65 |
# scGPT - INFO - | epoch   3 | 3400/3829 batches | lr 0.0001 | ms/batch 172.88 | loss 38.36 | mse 15.86 | mre 422035.20 |gepc 17.23 |
# scGPT - INFO - | epoch   3 | 3500/3829 batches | lr 0.0001 | ms/batch 171.09 | loss 53.30 | mse 17.91 | mre 520369.34 |gepc 26.20 |
# scGPT - INFO - | epoch   3 | 3600/3829 batches | lr 0.0001 | ms/batch 171.72 | loss 49.42 | mse 20.02 | mre 537540.48 |gepc 23.06 |
# scGPT - INFO - | epoch   3 | 3700/3829 batches | lr 0.0001 | ms/batch 171.72 | loss 46.03 | mse 19.01 | mre 514522.07 |gepc 21.42 |
# scGPT - INFO - | epoch   3 | 3800/3829 batches | lr 0.0001 | ms/batch 171.72 | loss 46.12 | mse 19.44 | mre 516685.42 |gepc 21.20 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   3 | time: 683.71s | valid loss/mse 19.5088 | mre 608287.4878
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 19.5088
# random masking at epoch   4, ratio of masked values in train:  0.3992
# scGPT - INFO - | epoch   4 | 100/3829 batches | lr 0.0001 | ms/batch 173.43 | loss 55.25 | mse 19.18 | mre 518325.79 |gepc 27.34 |
# scGPT - INFO - | epoch   4 | 200/3829 batches | lr 0.0001 | ms/batch 171.12 | loss 39.82 | mse 15.05 | mre 414772.96 |gepc 18.73 |
# scGPT - INFO - | epoch   4 | 300/3829 batches | lr 0.0001 | ms/batch 172.02 | loss 40.89 | mse 16.06 | mre 421017.65 |gepc 17.83 |
# scGPT - INFO - | epoch   4 | 400/3829 batches | lr 0.0001 | ms/batch 172.00 | loss 38.88 | mse 15.13 | mre 401401.39 |gepc 17.73 |
# scGPT - INFO - | epoch   4 | 500/3829 batches | lr 0.0001 | ms/batch 171.98 | loss 37.45 | mse 14.91 | mre 392716.41 |gepc 16.61 |
# scGPT - INFO - | epoch   4 | 600/3829 batches | lr 0.0001 | ms/batch 173.11 | loss 37.18 | mse 15.03 | mre 398398.67 |gepc 16.25 |
# scGPT - INFO - | epoch   4 | 700/3829 batches | lr 0.0001 | ms/batch 171.86 | loss 37.19 | mse 14.97 | mre 404740.77 |gepc 16.34 |
# scGPT - INFO - | epoch   4 | 800/3829 batches | lr 0.0001 | ms/batch 171.80 | loss 36.82 | mse 14.95 | mre 397335.91 |gepc 15.96 |
# scGPT - INFO - | epoch   4 | 900/3829 batches | lr 0.0001 | ms/batch 171.88 | loss 36.92 | mse 14.81 | mre 402736.26 |gepc 16.19 |
# scGPT - INFO - | epoch   4 | 1000/3829 batches | lr 0.0001 | ms/batch 171.92 | loss 37.92 | mse 15.09 | mre 396351.77 |gepc 17.00 |
# scGPT - INFO - | epoch   4 | 1100/3829 batches | lr 0.0001 | ms/batch 172.00 | loss 37.07 | mse 14.93 | mre 399605.19 |gepc 16.31 |
# scGPT - INFO - | epoch   4 | 1200/3829 batches | lr 0.0001 | ms/batch 172.52 | loss 40.27 | mse 14.35 | mre 402534.15 |gepc 17.89 |
# scGPT - INFO - | epoch   4 | 1300/3829 batches | lr 0.0001 | ms/batch 171.81 | loss 34.37 | mse 12.72 | mre 341182.73 |gepc 15.03 |
# scGPT - INFO - | epoch   4 | 1400/3829 batches | lr 0.0001 | ms/batch 171.85 | loss 33.71 | mse 12.54 | mre 342216.56 |gepc 14.81 |
# scGPT - INFO - | epoch   4 | 1500/3829 batches | lr 0.0001 | ms/batch 171.79 | loss 34.03 | mse 12.59 | mre 344535.67 |gepc 15.17 |
# scGPT - INFO - | epoch   4 | 1600/3829 batches | lr 0.0001 | ms/batch 172.97 | loss 33.19 | mse 12.77 | mre 346303.14 |gepc 14.25 |
# scGPT - INFO - | epoch   4 | 1700/3829 batches | lr 0.0001 | ms/batch 170.85 | loss 51.69 | mse 18.83 | mre 552251.36 |gepc 25.29 |
# scGPT - INFO - | epoch   4 | 1800/3829 batches | lr 0.0001 | ms/batch 171.50 | loss 43.82 | mse 18.06 | mre 537386.37 |gepc 20.14 |
# scGPT - INFO - | epoch   4 | 1900/3829 batches | lr 0.0001 | ms/batch 171.57 | loss 43.08 | mse 17.82 | mre 526378.85 |gepc 19.66 |
# scGPT - INFO - | epoch   4 | 2000/3829 batches | lr 0.0001 | ms/batch 171.71 | loss 43.05 | mse 17.60 | mre 511615.12 |gepc 20.19 |
# scGPT - INFO - | epoch   4 | 2100/3829 batches | lr 0.0001 | ms/batch 174.88 | loss 43.32 | mse 17.35 | mre 522015.82 |gepc 20.12 |
# scGPT - INFO - | epoch   4 | 2200/3829 batches | lr 0.0001 | ms/batch 171.79 | loss 46.98 | mse 16.44 | mre 479613.94 |gepc 22.55 |
# scGPT - INFO - | epoch   4 | 2300/3829 batches | lr 0.0001 | ms/batch 172.02 | loss 40.05 | mse 16.47 | mre 479664.48 |gepc 18.35 |
# scGPT - INFO - | epoch   4 | 2400/3829 batches | lr 0.0001 | ms/batch 171.97 | loss 38.87 | mse 16.28 | mre 472873.51 |gepc 17.48 |
# scGPT - INFO - | epoch   4 | 2500/3829 batches | lr 0.0001 | ms/batch 171.73 | loss 39.37 | mse 16.31 | mre 475588.42 |gepc 18.00 |
# scGPT - INFO - | epoch   4 | 2600/3829 batches | lr 0.0001 | ms/batch 171.92 | loss 57.24 | mse 21.10 | mre 590659.65 |gepc 28.02 |
# scGPT - INFO - | epoch   4 | 2700/3829 batches | lr 0.0001 | ms/batch 171.38 | loss 56.79 | mse 16.92 | mre 472361.45 |gepc 31.73 |
# scGPT - INFO - | epoch   4 | 2800/3829 batches | lr 0.0001 | ms/batch 171.84 | loss 34.80 | mse 12.73 | mre 359601.13 |gepc 15.05 |
# scGPT - INFO - | epoch   4 | 2900/3829 batches | lr 0.0001 | ms/batch 171.68 | loss 33.15 | mse 12.10 | mre 343513.94 |gepc 14.37 |
# scGPT - INFO - | epoch   4 | 3000/3829 batches | lr 0.0001 | ms/batch 171.76 | loss 47.52 | mse 16.85 | mre 449691.94 |gepc 23.62 |
# scGPT - INFO - | epoch   4 | 3100/3829 batches | lr 0.0001 | ms/batch 171.49 | loss 38.90 | mse 15.54 | mre 420738.35 |gepc 17.75 |
# scGPT - INFO - | epoch   4 | 3200/3829 batches | lr 0.0001 | ms/batch 171.60 | loss 38.70 | mse 15.31 | mre 415660.27 |gepc 18.05 |
# scGPT - INFO - | epoch   4 | 3300/3829 batches | lr 0.0001 | ms/batch 171.54 | loss 38.23 | mse 15.44 | mre 425608.16 |gepc 17.56 |
# scGPT - INFO - | epoch   4 | 3400/3829 batches | lr 0.0001 | ms/batch 171.58 | loss 37.66 | mse 15.41 | mre 418979.15 |gepc 17.04 |
# scGPT - INFO - | epoch   4 | 3500/3829 batches | lr 0.0001 | ms/batch 170.68 | loss 55.05 | mse 17.19 | mre 487946.76 |gepc 28.88 |
# scGPT - INFO - | epoch   4 | 3600/3829 batches | lr 0.0001 | ms/batch 172.74 | loss 45.90 | mse 19.04 | mre 518103.36 |gepc 21.24 |
# scGPT - INFO - | epoch   4 | 3700/3829 batches | lr 0.0001 | ms/batch 171.37 | loss 45.12 | mse 18.85 | mre 507206.12 |gepc 20.80 |
# scGPT - INFO - | epoch   4 | 3800/3829 batches | lr 0.0001 | ms/batch 171.28 | loss 44.82 | mse 18.87 | mre 509231.79 |gepc 20.63 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   4 | time: 683.84s | valid loss/mse 19.1817 | mre 647994.3182
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 19.1817
# random masking at epoch   5, ratio of masked values in train:  0.3992
# scGPT - INFO - | epoch   5 | 100/3829 batches | lr 0.0001 | ms/batch 173.20 | loss 48.54 | mse 18.75 | mre 531444.87 |gepc 21.47 |
# scGPT - INFO - | epoch   5 | 200/3829 batches | lr 0.0001 | ms/batch 171.22 | loss 37.31 | mse 14.60 | mre 409864.48 |gepc 16.86 |
# scGPT - INFO - | epoch   5 | 300/3829 batches | lr 0.0001 | ms/batch 171.98 | loss 42.37 | mse 16.08 | mre 427624.59 |gepc 18.48 |
# scGPT - INFO - | epoch   5 | 400/3829 batches | lr 0.0001 | ms/batch 171.74 | loss 37.09 | mse 14.89 | mre 384194.97 |gepc 16.31 |
# scGPT - INFO - | epoch   5 | 500/3829 batches | lr 0.0001 | ms/batch 172.03 | loss 36.80 | mse 14.92 | mre 393445.80 |gepc 16.07 |
# scGPT - INFO - | epoch   5 | 600/3829 batches | lr 0.0001 | ms/batch 172.27 | loss 36.54 | mse 14.76 | mre 400194.02 |gepc 15.90 |
# scGPT - INFO - | epoch   5 | 700/3829 batches | lr 0.0001 | ms/batch 173.99 | loss 36.01 | mse 14.62 | mre 394839.86 |gepc 15.71 |
# scGPT - INFO - | epoch   5 | 800/3829 batches | lr 0.0001 | ms/batch 171.97 | loss 36.33 | mse 14.84 | mre 398435.98 |gepc 15.77 |
# scGPT - INFO - | epoch   5 | 900/3829 batches | lr 0.0001 | ms/batch 171.74 | loss 35.74 | mse 14.51 | mre 383884.69 |gepc 15.59 |
# scGPT - INFO - | epoch   5 | 1000/3829 batches | lr 0.0001 | ms/batch 171.73 | loss 35.84 | mse 14.62 | mre 391997.75 |gepc 15.59 |
# scGPT - INFO - | epoch   5 | 1100/3829 batches | lr 0.0001 | ms/batch 171.72 | loss 36.38 | mse 14.91 | mre 394197.23 |gepc 15.77 |
# scGPT - INFO - | epoch   5 | 1200/3829 batches | lr 0.0001 | ms/batch 172.26 | loss 37.34 | mse 14.03 | mre 378270.32 |gepc 15.87 |
# scGPT - INFO - | epoch   5 | 1300/3829 batches | lr 0.0001 | ms/batch 171.57 | loss 32.79 | mse 12.51 | mre 338500.82 |gepc 13.89 |
# scGPT - INFO - | epoch   5 | 1400/3829 batches | lr 0.0001 | ms/batch 171.51 | loss 32.24 | mse 12.41 | mre 332091.66 |gepc 13.85 |
# scGPT - INFO - | epoch   5 | 1500/3829 batches | lr 0.0001 | ms/batch 171.63 | loss 31.60 | mse 12.25 | mre 339036.69 |gepc 13.75 |
# scGPT - INFO - | epoch   5 | 1600/3829 batches | lr 0.0001 | ms/batch 171.63 | loss 31.91 | mse 12.51 | mre 342008.04 |gepc 13.86 |
# scGPT - INFO - | epoch   5 | 1700/3829 batches | lr 0.0001 | ms/batch 171.83 | loss 47.91 | mse 17.98 | mre 542591.06 |gepc 22.85 |
# scGPT - INFO - | epoch   5 | 1800/3829 batches | lr 0.0001 | ms/batch 171.70 | loss 41.21 | mse 17.19 | mre 513796.69 |gepc 18.56 |
# scGPT - INFO - | epoch   5 | 1900/3829 batches | lr 0.0001 | ms/batch 171.47 | loss 40.67 | mse 17.11 | mre 513786.10 |gepc 18.49 |
# scGPT - INFO - | epoch   5 | 2000/3829 batches | lr 0.0001 | ms/batch 171.58 | loss 40.48 | mse 16.94 | mre 486490.31 |gepc 18.57 |
# scGPT - INFO - | epoch   5 | 2100/3829 batches | lr 0.0001 | ms/batch 171.74 | loss 41.68 | mse 16.99 | mre 521758.62 |gepc 18.97 |
# scGPT - INFO - | epoch   5 | 2200/3829 batches | lr 0.0001 | ms/batch 171.52 | loss 43.23 | mse 16.55 | mre 500259.33 |gepc 19.14 |
# scGPT - INFO - | epoch   5 | 2300/3829 batches | lr 0.0001 | ms/batch 171.60 | loss 38.94 | mse 15.77 | mre 469362.37 |gepc 18.13 |
# scGPT - INFO - | epoch   5 | 2400/3829 batches | lr 0.0001 | ms/batch 171.53 | loss 38.25 | mse 15.90 | mre 469355.78 |gepc 17.32 |
# scGPT - INFO - | epoch   5 | 2500/3829 batches | lr 0.0001 | ms/batch 171.62 | loss 38.55 | mse 16.13 | mre 472250.94 |gepc 17.46 |
# scGPT - INFO - | epoch   5 | 2600/3829 batches | lr 0.0001 | ms/batch 170.59 | loss 51.66 | mse 20.00 | mre 594465.24 |gepc 24.07 |
# scGPT - INFO - | epoch   5 | 2700/3829 batches | lr 0.0001 | ms/batch 172.44 | loss 40.64 | mse 15.32 | mre 435037.98 |gepc 18.07 |
# scGPT - INFO - | epoch   5 | 2800/3829 batches | lr 0.0001 | ms/batch 171.57 | loss 32.10 | mse 12.24 | mre 347600.90 |gepc 14.11 |
# scGPT - INFO - | epoch   5 | 2900/3829 batches | lr 0.0001 | ms/batch 171.62 | loss 31.57 | mse 12.35 | mre 348880.94 |gepc 13.84 |
# scGPT - INFO - | epoch   5 | 3000/3829 batches | lr 0.0001 | ms/batch 171.54 | loss 45.20 | mse 16.64 | mre 441863.58 |gepc 21.62 |
# scGPT - INFO - | epoch   5 | 3100/3829 batches | lr 0.0001 | ms/batch 171.65 | loss 37.48 | mse 15.37 | mre 417988.56 |gepc 16.76 |
# scGPT - INFO - | epoch   5 | 3200/3829 batches | lr 0.0001 | ms/batch 171.65 | loss 37.10 | mse 15.25 | mre 417790.28 |gepc 16.64 |
# scGPT - INFO - | epoch   5 | 3300/3829 batches | lr 0.0001 | ms/batch 171.49 | loss 36.78 | mse 15.25 | mre 419080.38 |gepc 16.42 |
# scGPT - INFO - | epoch   5 | 3400/3829 batches | lr 0.0001 | ms/batch 171.52 | loss 36.89 | mse 15.33 | mre 412962.19 |gepc 16.49 |
# scGPT - INFO - | epoch   5 | 3500/3829 batches | lr 0.0001 | ms/batch 170.81 | loss 56.64 | mse 16.71 | mre 476392.47 |gepc 31.19 |
# scGPT - INFO - | epoch   5 | 3600/3829 batches | lr 0.0001 | ms/batch 171.54 | loss 45.31 | mse 18.99 | mre 509027.50 |gepc 20.68 |
# scGPT - INFO - | epoch   5 | 3700/3829 batches | lr 0.0001 | ms/batch 172.59 | loss 43.80 | mse 18.57 | mre 500799.06 |gepc 19.93 |
# scGPT - INFO - | epoch   5 | 3800/3829 batches | lr 0.0001 | ms/batch 171.41 | loss 43.65 | mse 18.53 | mre 494367.80 |gepc 19.93 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   5 | time: 683.19s | valid loss/mse 18.2134 | mre 475202.5504
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 18.2134
# scGPT - INFO - Saving model to save/dev_AML-Feb05-12-52
# scGPT - INFO - Evaluating cls cell embeddings
# 100%|██████████| 4249/4249 [03:42<00:00, 19.10it/s]
# Recompute neighbors on rep X_scGPT instead of None
# Cluster for cluster_0.2 with leiden
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scib/metrics/clustering.py:96: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   cluster_function(adata, resolution=res, key_added=resolution_key, **kwargs)
# Cluster for cluster_0.4 with leiden
# Cluster for cluster_0.6 with leiden
# Cluster for cluster_0.8 with leiden
# Cluster for cluster_1.0 with leiden
# Cluster for cluster_1.2 with leiden
# Cluster for cluster_1.4 with leiden
# Cluster for cluster_1.6 with leiden
# Cluster for cluster_1.8 with leiden
# Cluster for cluster_2.0 with leiden
# NMI...
# ARI...
# Silhouette score...
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# PC regression...
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scanpy/preprocessing/_pca.py:377: FutureWarning: Argument `use_highly_variable` is deprecated, consider using the mask argument. Use_highly_variable=True can be called through mask_var="highly_variable". Use_highly_variable=False can be called through mask_var=None
#   warn(msg, FutureWarning)
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scanpy/preprocessing/_pca.py:377: FutureWarning: Argument `use_highly_variable` is deprecated, consider using the mask argument. Use_highly_variable=True can be called through mask_var="highly_variable". Use_highly_variable=False can be called through mask_var=None
#   warn(msg, FutureWarning)
# Graph connectivity...
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scib/metrics/graph_connectivity.py:56: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(labels)
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scib/metrics/graph_connectivity.py:56: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(labels)
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scib/metrics/graph_connectivity.py:56: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(labels)
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scib/metrics/graph_connectivity.py:56: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(labels)
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scib/metrics/graph_connectivity.py:56: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(labels)
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scib/metrics/graph_connectivity.py:56: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(labels)
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scib/metrics/graph_connectivity.py:56: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(labels)
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scib/metrics/graph_connectivity.py:56: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(labels)
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scib/metrics/graph_connectivity.py:56: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(labels)
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scib/metrics/graph_connectivity.py:56: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(labels)
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# scGPT - INFO -                                   0
# NMI_cluster/label          0.596879
# ARI_cluster/label          0.436113
# ASW_label                  0.544064
# ASW_label/batch            0.882629
# PCR_batch                  0.490885
# cell_cycle_conservation         NaN
# isolated_label_F1               NaN
# isolated_label_silhouette       NaN
# graph_conn                 0.943946
# kBET                            NaN
# iLISI                           NaN
# cLISI                           NaN
# hvg_overlap                     NaN
# trajectory                      NaN
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scib/metrics/graph_connectivity.py:56: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(labels)
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scib/metrics/graph_connectivity.py:56: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(labels)
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scib/metrics/graph_connectivity.py:56: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(labels)
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scib/metrics/graph_connectivity.py:56: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(labels)
# scGPT - INFO - Biological Conservation Metrics:
# ASW (cell-type): 0.5441, graph cLISI: nan, isolated label silhouette: nan,
# Batch Effect Removal Metrics:
# PCR_batch: 0.4909, ASW (batch): 0.8826, graph connectivity: 0.9439, graph iLISI: nan
# random masking at epoch   6, ratio of masked values in train:  0.3992
# scGPT - INFO - | epoch   6 | 100/3829 batches | lr 0.0001 | ms/batch 175.22 | loss 49.15 | mse 18.87 | mre 498810.26 |gepc 21.81 |
# scGPT - INFO - | epoch   6 | 200/3829 batches | lr 0.0001 | ms/batch 174.56 | loss 36.05 | mse 14.44 | mre 394026.95 |gepc 15.73 |
# scGPT - INFO - | epoch   6 | 300/3829 batches | lr 0.0001 | ms/batch 173.06 | loss 39.75 | mse 15.60 | mre 416101.57 |gepc 16.91 |
# scGPT - INFO - | epoch   6 | 400/3829 batches | lr 0.0001 | ms/batch 172.71 | loss 36.16 | mse 14.60 | mre 387568.20 |gepc 15.82 |
# scGPT - INFO - | epoch   6 | 500/3829 batches | lr 0.0001 | ms/batch 172.26 | loss 35.62 | mse 14.48 | mre 379373.79 |gepc 15.43 |
# scGPT - INFO - | epoch   6 | 600/3829 batches | lr 0.0001 | ms/batch 173.32 | loss 35.55 | mse 14.47 | mre 380932.21 |gepc 15.43 |
# scGPT - INFO - | epoch   6 | 700/3829 batches | lr 0.0001 | ms/batch 172.85 | loss 35.92 | mse 14.75 | mre 391419.38 |gepc 15.57 |
# scGPT - INFO - | epoch   6 | 800/3829 batches | lr 0.0001 | ms/batch 172.78 | loss 35.58 | mse 14.54 | mre 393236.93 |gepc 15.48 |
# scGPT - INFO - | epoch   6 | 900/3829 batches | lr 0.0001 | ms/batch 173.56 | loss 35.25 | mse 14.50 | mre 388848.40 |gepc 15.21 |
# scGPT - INFO - | epoch   6 | 1000/3829 batches | lr 0.0001 | ms/batch 172.26 | loss 35.27 | mse 14.43 | mre 384033.93 |gepc 15.27 |
# scGPT - INFO - | epoch   6 | 1100/3829 batches | lr 0.0001 | ms/batch 172.17 | loss 35.10 | mse 14.37 | mre 386227.01 |gepc 15.23 |
# scGPT - INFO - | epoch   6 | 1200/3829 batches | lr 0.0001 | ms/batch 172.82 | loss 39.90 | mse 13.91 | mre 366083.30 |gepc 18.37 |
# scGPT - INFO - | epoch   6 | 1300/3829 batches | lr 0.0001 | ms/batch 171.90 | loss 32.25 | mse 12.39 | mre 341450.28 |gepc 13.99 |
# scGPT - INFO - | epoch   6 | 1400/3829 batches | lr 0.0001 | ms/batch 172.06 | loss 31.56 | mse 12.32 | mre 346009.85 |gepc 13.87 |
# scGPT - INFO - | epoch   6 | 1500/3829 batches | lr 0.0001 | ms/batch 172.14 | loss 30.93 | mse 12.29 | mre 337234.59 |gepc 13.45 |
# scGPT - INFO - | epoch   6 | 1600/3829 batches | lr 0.0001 | ms/batch 172.12 | loss 30.74 | mse 12.21 | mre 331414.19 |gepc 13.41 |
# scGPT - INFO - | epoch   6 | 1700/3829 batches | lr 0.0001 | ms/batch 172.16 | loss 47.05 | mse 17.64 | mre 505413.74 |gepc 22.32 |
# scGPT - INFO - | epoch   6 | 1800/3829 batches | lr 0.0001 | ms/batch 173.24 | loss 40.27 | mse 16.97 | mre 496674.33 |gepc 18.22 |
# scGPT - INFO - | epoch   6 | 1900/3829 batches | lr 0.0001 | ms/batch 174.45 | loss 39.79 | mse 16.82 | mre 499043.02 |gepc 18.03 |
# scGPT - INFO - | epoch   6 | 2000/3829 batches | lr 0.0001 | ms/batch 173.05 | loss 39.83 | mse 17.00 | mre 511491.73 |gepc 17.92 |
# scGPT - INFO - | epoch   6 | 2100/3829 batches | lr 0.0001 | ms/batch 172.69 | loss 40.42 | mse 16.66 | mre 487144.43 |gepc 18.12 |
# scGPT - INFO - | epoch   6 | 2200/3829 batches | lr 0.0001 | ms/batch 173.05 | loss 43.66 | mse 15.90 | mre 467612.28 |gepc 19.82 |
# scGPT - INFO - | epoch   6 | 2300/3829 batches | lr 0.0001 | ms/batch 172.33 | loss 39.58 | mse 15.76 | mre 456836.25 |gepc 18.54 |
# scGPT - INFO - | epoch   6 | 2400/3829 batches | lr 0.0001 | ms/batch 172.80 | loss 37.91 | mse 15.88 | mre 468594.21 |gepc 17.11 |
# scGPT - INFO - | epoch   6 | 2500/3829 batches | lr 0.0001 | ms/batch 172.73 | loss 37.70 | mse 15.73 | mre 465598.27 |gepc 17.09 |
# scGPT - INFO - | epoch   6 | 2600/3829 batches | lr 0.0001 | ms/batch 170.80 | loss 47.55 | mse 18.77 | mre 554736.28 |gepc 21.66 |
# scGPT - INFO - | epoch   6 | 2700/3829 batches | lr 0.0001 | ms/batch 171.42 | loss 40.42 | mse 15.39 | mre 439056.09 |gepc 18.55 |
# scGPT - INFO - | epoch   6 | 2800/3829 batches | lr 0.0001 | ms/batch 172.17 | loss 31.31 | mse 12.19 | mre 340873.22 |gepc 13.65 |
# scGPT - INFO - | epoch   6 | 2900/3829 batches | lr 0.0001 | ms/batch 172.98 | loss 30.25 | mse 11.73 | mre 327982.91 |gepc 13.29 |
# scGPT - INFO - | epoch   6 | 3000/3829 batches | lr 0.0001 | ms/batch 171.90 | loss 45.80 | mse 16.15 | mre 456692.52 |gepc 22.86 |
# scGPT - INFO - | epoch   6 | 3100/3829 batches | lr 0.0001 | ms/batch 171.84 | loss 37.60 | mse 15.41 | mre 415016.27 |gepc 16.94 |
# scGPT - INFO - | epoch   6 | 3200/3829 batches | lr 0.0001 | ms/batch 171.73 | loss 36.85 | mse 15.05 | mre 405359.62 |gepc 16.57 |
# scGPT - INFO - | epoch   6 | 3300/3829 batches | lr 0.0001 | ms/batch 171.88 | loss 36.11 | mse 14.92 | mre 406049.13 |gepc 15.98 |
# scGPT - INFO - | epoch   6 | 3400/3829 batches | lr 0.0001 | ms/batch 171.69 | loss 36.49 | mse 15.00 | mre 404848.25 |gepc 16.48 |
# scGPT - INFO - | epoch   6 | 3500/3829 batches | lr 0.0001 | ms/batch 170.51 | loss 48.53 | mse 16.66 | mre 451324.39 |gepc 23.09 |
# scGPT - INFO - | epoch   6 | 3600/3829 batches | lr 0.0001 | ms/batch 171.29 | loss 45.33 | mse 18.89 | mre 501816.46 |gepc 20.52 |
# scGPT - INFO - | epoch   6 | 3700/3829 batches | lr 0.0001 | ms/batch 171.61 | loss 43.40 | mse 18.46 | mre 496552.33 |gepc 19.72 |
# scGPT - INFO - | epoch   6 | 3800/3829 batches | lr 0.0001 | ms/batch 171.46 | loss 42.97 | mse 18.35 | mre 488414.03 |gepc 19.56 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   6 | time: 685.90s | valid loss/mse 18.1267 | mre 600765.8915
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 18.1267
# random masking at epoch   7, ratio of masked values in train:  0.3992
# scGPT - INFO - | epoch   7 | 100/3829 batches | lr 0.0001 | ms/batch 174.02 | loss 47.77 | mse 18.15 | mre 526323.90 |gepc 21.25 |
# scGPT - INFO - | epoch   7 | 200/3829 batches | lr 0.0001 | ms/batch 171.54 | loss 37.95 | mse 14.64 | mre 394201.58 |gepc 17.36 |
# scGPT - INFO - | epoch   7 | 300/3829 batches | lr 0.0001 | ms/batch 171.19 | loss 41.28 | mse 15.71 | mre 421432.49 |gepc 18.09 |
# scGPT - INFO - | epoch   7 | 400/3829 batches | lr 0.0001 | ms/batch 171.20 | loss 35.83 | mse 14.60 | mre 383209.09 |gepc 15.53 |
# scGPT - INFO - | epoch   7 | 500/3829 batches | lr 0.0001 | ms/batch 171.27 | loss 35.73 | mse 14.62 | mre 393257.68 |gepc 15.58 |
# scGPT - INFO - | epoch   7 | 600/3829 batches | lr 0.0001 | ms/batch 171.17 | loss 35.63 | mse 14.65 | mre 386501.74 |gepc 15.48 |
# scGPT - INFO - | epoch   7 | 700/3829 batches | lr 0.0001 | ms/batch 171.23 | loss 35.38 | mse 14.56 | mre 391127.20 |gepc 15.36 |
# scGPT - INFO - | epoch   7 | 800/3829 batches | lr 0.0001 | ms/batch 171.17 | loss 34.74 | mse 14.31 | mre 373888.14 |gepc 15.02 |
# scGPT - INFO - | epoch   7 | 900/3829 batches | lr 0.0001 | ms/batch 171.14 | loss 34.63 | mse 14.25 | mre 378786.90 |gepc 14.94 |
# scGPT - INFO - | epoch   7 | 1000/3829 batches | lr 0.0001 | ms/batch 171.30 | loss 35.05 | mse 14.45 | mre 383566.37 |gepc 15.15 |
# ...
# scGPT - INFO - | epoch  10 | 2400/3829 batches | lr 0.0000 | ms/batch 170.93 | loss 35.42 | mse 15.04 | mre 451834.09 |gepc 15.66 |
# scGPT - INFO - | epoch  10 | 2500/3829 batches | lr 0.0000 | ms/batch 171.16 | loss 35.92 | mse 15.34 | mre 456161.83 |gepc 15.92 |
# scGPT - INFO - | epoch  10 | 2600/3829 batches | lr 0.0000 | ms/batch 170.99 | loss 43.61 | mse 17.67 | mre 507375.67 |gepc 19.56 |
# scGPT - INFO - | epoch  10 | 2700/3829 batches | lr 0.0000 | ms/batch 170.82 | loss 36.23 | mse 14.16 | mre 396501.22 |gepc 15.96 |
# scGPT - INFO - | epoch  10 | 2800/3829 batches | lr 0.0000 | ms/batch 171.17 | loss 29.80 | mse 11.78 | mre 331775.27 |gepc 12.84 |
# scGPT - INFO - | epoch  10 | 2900/3829 batches | lr 0.0000 | ms/batch 171.25 | loss 27.74 | mse 10.95 | mre 313753.65 |gepc 11.89 |
# scGPT - INFO - | epoch  10 | 3000/3829 batches | lr 0.0000 | ms/batch 170.86 | loss 37.97 | mse 14.85 | mre 410658.59 |gepc 17.13 |
# scGPT - INFO - | epoch  10 | 3100/3829 batches | lr 0.0000 | ms/batch 170.94 | loss 34.85 | mse 14.42 | mre 391708.73 |gepc 15.45 |
# scGPT - INFO - | epoch  10 | 3200/3829 batches | lr 0.0000 | ms/batch 170.98 | loss 34.89 | mse 14.58 | mre 394841.26 |gepc 15.46 |
# scGPT - INFO - | epoch  10 | 3300/3829 batches | lr 0.0000 | ms/batch 170.89 | loss 34.31 | mse 14.36 | mre 394763.82 |gepc 15.15 |
# scGPT - INFO - | epoch  10 | 3400/3829 batches | lr 0.0000 | ms/batch 171.06 | loss 34.17 | mse 14.26 | mre 390067.34 |gepc 15.17 |
# scGPT - INFO - | epoch  10 | 3500/3829 batches | lr 0.0000 | ms/batch 171.64 | loss 43.01 | mse 15.64 | mre 421569.75 |gepc 20.01 |
# scGPT - INFO - | epoch  10 | 3600/3829 batches | lr 0.0000 | ms/batch 173.56 | loss 42.86 | mse 17.99 | mre 486002.79 |gepc 19.40 |
# scGPT - INFO - | epoch  10 | 3700/3829 batches | lr 0.0000 | ms/batch 171.87 | loss 41.59 | mse 17.68 | mre 469337.63 |gepc 18.87 |
# scGPT - INFO - | epoch  10 | 3800/3829 batches | lr 0.0000 | ms/batch 171.60 | loss 41.17 | mse 17.58 | mre 469261.97 |gepc 18.66 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  10 | time: 682.74s | valid loss/mse 16.6767 | mre 520859.9290
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 16.6767
# scGPT - INFO - Saving model to save/dev_AML-Feb05-12-52
# scGPT - INFO - Evaluating cls cell embeddings
# 100%|██████████| 4249/4249 [03:42<00:00, 19.10it/s]
# Recompute neighbors on rep X_scGPT instead of None
# Cluster for cluster_0.2 with leiden
# Cluster for cluster_0.4 with leiden
# Cluster for cluster_0.6 with leiden
# Cluster for cluster_0.8 with leiden
# Cluster for cluster_1.0 with leiden
# Cluster for cluster_1.2 with leiden
# Cluster for cluster_1.4 with leiden
# Cluster for cluster_1.6 with leiden
# Cluster for cluster_1.8 with leiden
# Cluster for cluster_2.0 with leiden
# NMI...
# ARI...
# Silhouette score...
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scanpy/preprocessing/_pca.py:377: FutureWarning: Argument `use_highly_variable` is deprecated, consider using the mask argument. Use_highly_variable=True can be called through mask_var="highly_variable". Use_highly_variable=False can be called through mask_var=None
#   warn(msg, FutureWarning)
# PC regression...
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scanpy/preprocessing/_pca.py:377: FutureWarning: Argument `use_highly_variable` is deprecated, consider using the mask argument. Use_highly_variable=True can be called through mask_var="highly_variable". Use_highly_variable=False can be called through mask_var=None
#   warn(msg, FutureWarning)
# Graph connectivity...
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scib/metrics/graph_connectivity.py:56: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(labels)
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scib/metrics/graph_connectivity.py:56: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(labels)
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scib/metrics/graph_connectivity.py:56: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(labels)
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scib/metrics/graph_connectivity.py:56: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(labels)
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scib/metrics/graph_connectivity.py:56: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(labels)
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scib/metrics/graph_connectivity.py:56: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(labels)
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scib/metrics/graph_connectivity.py:56: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(labels)
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scib/metrics/graph_connectivity.py:56: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(labels)
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scib/metrics/graph_connectivity.py:56: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(labels)
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scib/metrics/graph_connectivity.py:56: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(labels)
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# scGPT - INFO -                                   0
# NMI_cluster/label          0.625881
# ARI_cluster/label          0.509820
# ASW_label                  0.550493
# ASW_label/batch            0.879729
# PCR_batch                  0.472868
# cell_cycle_conservation         NaN
# isolated_label_F1               NaN
# isolated_label_silhouette       NaN
# graph_conn                 0.954439
# kBET                            NaN
# iLISI                           NaN
# cLISI                           NaN
# hvg_overlap                     NaN
# trajectory                      NaN
# scGPT - INFO - Biological Conservation Metrics:
# ASW (cell-type): 0.5505, graph cLISI: nan, isolated label silhouette: nan,
# Batch Effect Removal Metrics:
# PCR_batch: 0.4729, ASW (batch): 0.8797, graph connectivity: 0.9544, graph iLISI: nan
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scib/metrics/graph_connectivity.py:56: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(labels)
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scib/metrics/graph_connectivity.py:56: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(labels)
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scib/metrics/graph_connectivity.py:56: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(labels)
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /users/wag9iz/.conda/envs/rtd/lib/python3.9/site-packages/scib/metrics/graph_connectivity.py:56: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(labels)

# %%
torch.save(best_model.state_dict(), save_dir / "best_model.pt")

# %%
artifact = wandb.Artifact(f"best_model", type="model")
glob_str = os.path.join(save_dir, "best_model.pt")
artifact.add_file(glob_str)
run.log_artifact(artifact)

run.finish()
wandb.finish()
gc.collect()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 4
#       2 glob_str = os.path.join(save_dir, "best_model.pt")
#       3 artifact.add_file(glob_str)
# ----> 4 run.log_artifact(artifact)
#       6 run.finish()
#       7 wandb.finish()
#
# File ~/.conda/envs/rtd/lib/python3.9/site-packages/wandb/sdk/wandb_run.py:400, in _log_to_run.<locals>.wrapper(self, *args, **kwargs)
#     397     run_id = self._attach_id
#     399 with wb_logging.log_to_run(run_id):
# --> 400     return func(self, *args, **kwargs)
#
# File ~/.conda/envs/rtd/lib/python3.9/site-packages/wandb/sdk/wandb_run.py:458, in _raise_if_finished.<locals>.wrapper_fn(self, *args, **kwargs)
#     455 @functools.wraps(func)
#     456 def wrapper_fn(self: Run, *args: _P.args, **kwargs: _P.kwargs) -> _T:
#     457     if not getattr(self, "_is_finished", False):
# --> 458         return func(self, *args, **kwargs)
#     460     message = (
#     461         f"Run ({self.id}) is finished. The call to"
#     462         f" `{func.__name__}` will be ignored."
#     463         f" Please make sure that you are using an active run."
#     464     )
#     466     raise UsageError(message)
#
# File ~/.conda/envs/rtd/lib/python3.9/site-packages/wandb/sdk/wandb_run.py:445, in _attach.<locals>.wrapper(self, *args, **kwargs)
#     442     finally:
#     443         _is_attaching = ""
# --> 445 return func(self, *args, **kwargs)
#
# File ~/.conda/envs/rtd/lib/python3.9/site-packages/wandb/sdk/wandb_run.py:3174, in Run.log_artifact(self, artifact_or_path, name, type, aliases, tags)
#    3139 @_log_to_run
#    3140 @_raise_if_finished
#    3141 @_attach
#    (...)
#    3148     tags: list[str] | None = None,
#    3149 ) -> Artifact:
#    3150     """Declare an artifact as an output of a run.
#    3151
#    3152     Args:
#    (...)
#    3172         An `Artifact` object.
#    3173     """
# -> 3174     return self._log_artifact(
#    3175         artifact_or_path,
#    3176         name=name,
#    3177         type=type,
#    3178         aliases=aliases,
#    3179         tags=tags,
#    3180     )
#
# File ~/.conda/envs/rtd/lib/python3.9/site-packages/wandb/sdk/wandb_run.py:3316, in Run._log_artifact(self, artifact_or_path, name, type, aliases, tags, distributed_id, finalize, is_user_created, use_after_commit)
#    3310     tags = validate_tags(tags)
#    3312 artifact, aliases = self._prepare_artifact(
#    3313     artifact_or_path, name, type, aliases
#    3314 )
# -> 3316 artifact.metadata = {**artifact.metadata}  # triggers validation
#    3318 artifact.distributed_id = distributed_id
#    3319 self._assert_can_log_artifact(artifact)
#
# File ~/.conda/envs/rtd/lib/python3.9/site-packages/wandb/sdk/artifacts/artifact.py:883, in Artifact.metadata(self, metadata)
#     879 if self.is_link:
#     880     wandb.termwarn(
#     881         "Editing the metadata of this linked artifact will edit the metadata for the source artifact and it's linked artifacts as well."
#     882     )
# --> 883 self._metadata = validate_metadata(metadata)
#
# File ~/.conda/envs/rtd/lib/python3.9/functools.py:888, in singledispatch.<locals>.wrapper(*args, **kw)
#     884 if not args:
#     885     raise TypeError(f'{funcname} requires at least '
#     886                     '1 positional argument')
# --> 888 return dispatch(args[0].__class__)(*args, **kw)
#
# File ~/.conda/envs/rtd/lib/python3.9/site-packages/wandb/sdk/artifacts/_validators.py:218, in _(metadata)
#     213 @validate_metadata.register(dict)
#     214 def _(metadata: dict[str, Any]) -> dict[str, Any]:
#     215     # NOTE: The backend doesn't currently allow JS-compatible `+/-Infinity` values.
#     216     # Forbid them here to avoid surprises, but revisit if we add future backend support.
#     217     # Note that prior behavior already converts `NaN` values to `None` (client-side).
# --> 218     metadata = from_json(json.dumps(json_friendly_val(metadata), allow_nan=False))
#     219     if len(metadata) > MAX_ARTIFACT_METADATA_KEYS:
#     220         raise ValueError(
#     221             f"Artifact must not have more than {MAX_ARTIFACT_METADATA_KEYS!r} metadata keys."
#     222         )
#
# File ~/.conda/envs/rtd/lib/python3.9/site-packages/wandb/_pydantic/utils.py:35, in from_json(s)
#      33 def from_json(s: str | bytes) -> Any:
#      34     """Quickly deserialize a JSON string to a Python object."""
# ---> 35     return pydantic_core.from_json(s)
#
# AttributeError: module 'pydantic_core' has no attribute 'from_json'
